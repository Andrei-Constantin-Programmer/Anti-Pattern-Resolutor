# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.chat_models import ChatOpenAI  # Or use Ollama/Mistral
from langchain_ollama.llms import OllamaLLM
llm = OllamaLLM(model="granite3.3:8b")  # Or "llama2", "codellama", etc.

# Instead of llm.name, use:
print(f"Model: {llm.model}")  # This will show "granite3.3:8b"
# Or to see all available attributes:
print(f"LLM type: {type(llm).__name__}")  # This will show "OllamaLLM"


# Pattern Scanner Agent
pattern_prompt = PromptTemplate(
    input_variables=["code"],
    template="You are a code reviewer. Find and name any anti-patterns in this Java code:\n\n{code}"
)
PatternScannerAgent = LLMChain(llm=llm, prompt=pattern_prompt)

# Refactoring Agent
refactor_prompt = PromptTemplate(
    input_variables=["code", "issues"],
    template="Refactor the Java code below by addressing the following anti-patterns: {issues}\n\nCode:\n{code}"
)
RefactoringAgent = LLMChain(llm=llm, prompt=refactor_prompt)
# Out:
# Model: granite3.3:8b
# LLM type: OllamaLLM
# /tmp/ipykernel_2177642/2156565391.py:18: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   PatternScannerAgent = LLMChain(llm=llm, prompt=pattern_prompt)

# %%
from langgraph.graph import StateGraph
from typing import TypedDict

# Shared context object (like MCP envelope)
class AgentState(TypedDict): 
    code: str  # The original code to be scanned and refactored
    issues: str  # Issues found by the pattern scanner
    refactored: str  # Refactored code after addressing issues
    # def __init__(self, code: str, issues: str = "", refactored: str = ""):
    #     self.code = code
    #     self.issues = issues
    #     self.refactored = refactored

# Pattern Scanner Node

def scan_for_patterns(state: AgentState):
    print("🔍 Scanning for anti-patterns...")
    state["issues"] = PatternScannerAgent.run(code=state["code"])
    return state

# Refactoring Agent Node

def refactor_code(state: AgentState):
    print("🛠️ Refactoring code...")
    state["refactored"] = RefactoringAgent.run(code=state["code"], issues=state["issues"])
    return state

# Terminal Display Node

def display_results(state: AgentState):
    print("✅ Done.\nIssues Found:\n", state["issues"])
    print("Refactored Code:\n", state["refactored"])
    return state

# %%
graph = StateGraph(AgentState)
graph.add_node("scan_for_patterns", scan_for_patterns)
graph.add_node("refactor_code", refactor_code)
graph.add_node("display_results", display_results)

# Define flow: Scanner → Refactorer → Display
graph.set_entry_point("scan_for_patterns")
graph.add_edge("scan_for_patterns", "refactor_code")
graph.add_edge("refactor_code", "display_results")

# Compile the FSM graph
agent_pipeline = graph.compile()

# %%
# Sample legacy code input
legacy_code = """
public class ApplicationManager {
    private List<String> users = new ArrayList<>();
    private List<String> logs = new ArrayList<>();
 
    public void addUser(String user) {
        users.add(user);
        logs.add("User added: " + user);
    }
 
    public void removeUser(String user) {
        users.remove(user);
        logs.add("User removed: " + user);
    }
 
    public void logEvent(String event) {
        logs.add(event);
    }
 
    public void printReport() {
        System.out.println("=== Users ===");
        for (String user : users) {
            System.out.println(user);
        }
 
        System.out.println("=== Logs ===");
        for (String log : logs) {
            System.out.println(log);
        }
    }
 
    public void backupData() {
        // Placeholder: pretend this backs up all data
        System.out.println("Backing up users and logs...");
    }
}
"""

initial_state = AgentState(code=legacy_code)
final_state = agent_pipeline.invoke(initial_state)
# Out:
# 🔍 Scanning for anti-patterns...
# 🛠️ Refactoring code...
# ✅ Done.
# Issues Found:
#  1. **God Class Anti-pattern**: The `ApplicationManager` class is handling multiple responsibilities, including managing users, logging events, printing reports, and backing up data. This violates the Single Responsibility Principle (SRP), which states that a class should have only one reason to change.
#
# 2. **Data Duplication**: The `users` list stores actual user data, while the `logs` list records events related to those users. There is no clear separation of concerns between data storage and event logging. This could lead to inconsistencies if the formats or structures of these lists diverge.
#
# 3. **Lack of Error Handling**: The methods like `addUser`, `removeUser`, and `backupData` do not handle potential exceptions, such as adding a null user or encountering issues while backing up data. Proper exception handling should be included to make the code more robust.
#
# 4. **No Encapsulation**: Both `users` and `logs` lists are public, allowing direct modification from outside the class. This breaks encapsulation and exposes internal state, making it harder to maintain and evolve the class in the future without unintended side effects.
#
# 5. **Lack of Data Validation**: There's no input validation for user strings in methods like `addUser` or `removeUser`. This could lead to issues if unexpected values are passed as arguments. Input validation should be implemented to ensure only valid data is processed by the class.
#
# 6. **Tight Coupling**: The `printReport` method tightly couples the reporting functionality with the internal state of the class (`users` and `logs`). This violates the principle of loose coupling, as changes in the reporting mechanism would require modifications to the data management part of the code.
#
# To improve this design, consider separating concerns into distinct classes. For example, you could have separate classes for user management, event logging, and report generation, each with their own responsibilities and clear interfaces. This would adhere better to SOLID principles, leading to more maintainable and extensible code.
# Refactored Code:
#  ```java
# // UserManagement.java
# import java.util.ArrayList;
# import java.util.List;
#
# public class UserManagement {
#     private final List<String> users = new ArrayList<>();
#
#     public synchronized void addUser(String user) {
#         if (user == null || user.isEmpty()) {
#             throw new IllegalArgumentException("User cannot be null or empty.");
#         }
#         users.add(user);
#     }
#
#     public synchronized boolean removeUser(String user) {
#         return users.remove(user);
#     }
#
#     private List<String> getUsers() {
#         return new ArrayList<>(users); // Return a copy to avoid external modification
#     }
# }
#
# // EventLogger.java
# import java.util.ArrayList;
# import java.util.List;
#
# public class EventLogger {
#     private final List<String> logs = new ArrayList<>();
#
#     public synchronized void logEvent(String event) {
#         if (event == null || event.isEmpty()) {
#             throw new IllegalArgumentException("Event cannot be null or empty.");
#         }
#         logs.add(event);
#     }
#
#     private List<String> getLogs() {
#         return new ArrayList<>(logs); // Return a copy to avoid external modification
#     }
# }
#
# // ReportGenerator.java
# public class ReportGenerator {
#     public void generateReport(UserManagement userManagement, EventLogger eventLogger) {
#         System.out.println("=== Users ===");
#         for (String user : userManagement.getUsers()) {
#             System.out.println(user);
#         }
#
#         System.out.println("=== Logs ===");
#         for (String log : eventLogger.getLogs()) {
#             System.out.println(log);
#         }
#     }
# }
#
# // ApplicationManager.java (refactored)
# import java.util.List;
#
# public class ApplicationManager {
#     private final UserManagement userManagement = new UserManagement();
#     private final EventLogger eventLogger = new EventLogger();
#
#     public void addUser(String user) {
#         try {
#             userManagement.addUser(user);
#             eventLogger.logEvent("User added: " + user);
#         } catch (IllegalArgumentException e) {
#             System.err.println(e.getMessage());
#         }
#     }
#
#     public boolean removeUser(String user) {
#         return userManagement.removeUser(user);
#     }
#
#     public void logEvent(String event) {
#         try {
#             eventLogger.logEvent(event);
#         } catch (IllegalArgumentException e) {
#             System.err.println(e.getMessage());
#         }
#     }
#
#     public void backupData() {
#         // Placeholder: pretend this backs up all data by serializing UserManagement and EventLogger
#         try {
#             // Assuming serialization is handled elsewhere for simplicity
#             System.out.println("Backing up user management and event logger data...");
#         } catch (Exception e) {
#             System.err.println("Error during backup: " + e.getMessage());
#         }
#     }
#
#     public void printReport() {
#         ReportGenerator reportGenerator = new ReportGenerator();
#         reportGenerator.generateReport(userManagement, eventLogger);
#     }
# }
# ```
#
# ### Explanation of Changes:
#
# 1. **God Class Refactoring**:
#    - Created separate classes `UserManagement`, `EventLogger`, and `ReportGenerator`.
#    - Each class has a single responsibility: managing users, logging events, and generating reports, respectively.
#    - `ApplicationManager` now delegates to these classes instead of handling multiple responsibilities directly.
#
# 2. **Data Duplication**:
#    - `UserManagement` and `EventLogger` each maintain their own lists (`users` and `logs`).
#    - To prevent direct modification from outside, they provide getter methods that return copies of the internal lists (`getUsers()` and `getLogs()`).
#
# 3. **Error Handling**:
#    - Added checks within `addUser` and `logEvent` for null or empty inputs, throwing appropriate exceptions if invalid data is provided.
#    - The `ApplicationManager` now catches these exceptions and prints error messages instead of allowing the application to crash.
#
# 4. **Encapsulation**:
#    - Made user lists and logs private within their respective classes, ensuring they can only be accessed or modified via well-defined methods (getters).
#
# 5. **Data Validation**:
#    - Input validation is now done in `addUser` and `logEvent`, ensuring that null or empty strings are not processed.
#
# 6. **Loose Coupling**:
#    - The `generateReport` method in `ReportGenerator` takes instances of `UserManagement` and `EventLogger`. This ensures that report generation logic is decoupled from the internal state management, allowing for easier future modifications without affecting data handling.
#
# This refactored code now adheres to SOLID principles more closely, making it easier to maintain, extend, and test each component independently.
